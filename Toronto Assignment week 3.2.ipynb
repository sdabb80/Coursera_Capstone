# %%
#Import the necessary libraries 
import pandas as pd
# !pip install geocoder
import geocoder
# Out:
# ...
#     100% |████████████████████████████████| 102kB 20.5MB/s
# ...

# %%
#Read the csv dataframe created as toronto file 
df_toronto = pd.read_csv('Toronto.csv').set_index("PostalCode")
df_toronto.head()
# Out:
#                 Borough                            Neighborhood
# PostalCode
# M1B         Scarborough                          Malvern, Rouge
# M1C         Scarborough  Highland Creek, Port Union, Rouge Hill
# M1E         Scarborough       Guildwood, Morningside, West Hill
# M1G         Scarborough                                  Woburn
# M1H         Scarborough                               Cedarbrae

# %%
#read coordinates from given csv file 
df_csv = pd.read_csv("Geospatial_Coordinates.csv").set_index("Postal Code")
df_csv.head()
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476

# %%
#combine of the 2 tables: Toronto table created in assignment one (df) and Geospatial_Coordinates csv file (df_csv)
Combined_table = df_toronto.join(df_csv)
Combined_table
# Out:
#                      Borough  \
# PostalCode
# M1B              Scarborough
# M1C              Scarborough
# M1E              Scarborough
# M1G              Scarborough
# M1H              Scarborough
# M1J              Scarborough
# M1K              Scarborough
# M1L              Scarborough
# M1M              Scarborough
# M1N              Scarborough
# M1P              Scarborough
# M1R              Scarborough
# M1S              Scarborough
# M1T              Scarborough
# M1V              Scarborough
# M1W              Scarborough
# M1X              Scarborough
# M2H               North York
# M2J               North York
# M2K               North York
# M2L               North York
# M2M               North York
# M2N               North York
# M2P               North York
# M2R               North York
# M3A               North York
# M3B               North York
# M3C               North York
# M3H               North York
# M3J               North York
# ...

# %%
#Saved the above table as maintable inclusive of lan and lng. for further use
Combined_table.to_csv('maintable.csv', index=False)
